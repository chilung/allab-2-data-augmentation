# %%
# %matplotlib inline

# %%
# License: BSD
# Author: Sasank Chilamkurthy

from __future__ import print_function, division

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy

plt.ion()   # interactive mode

# %%
# Data augmentation and normalization for training
# Just normalization for validation
data_transforms = {
    'train': transforms.Compose([
        #transforms.Resize(256),
        #transforms.CenterCrop(224),
        transforms.RandomResizedCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.5548, 0.4508, 0.3435], [0.2281, 0.2384, 0.2376])
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.5604, 0.4540, 0.3481], [0.2260, 0.2367, 0.2352])
    ]),
    'test': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.5604, 0.4540, 0.3481], [0.2260, 0.2367, 0.2352])
    ]),
}

data_dir = '../data/food/'
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val', 'test']}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=8,
                                             shuffle=True, num_workers=4)
              for x in ['train', 'val', 'test']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val', 'test']}
class_names = image_datasets['train'].classes

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
#device = torch.device("cpu")
# Out:
# cuda:0

# %% [markdown]
# Visualize a few images
# ^^^^^^^^^^^^^^^^^^^^^^
# Let's visualize a few training images so as to understand the data
# augmentations.

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.5548, 0.4508, 0.3435])
    std = np.array([0.2281, 0.2384, 0.2376])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])

# %% [markdown]
# Training the model
# ------------------
#
# Now, let's write a general function to train a model. Here, we will
# illustrate:
#
# -  Scheduling the learning rate
# -  Saving the best model
#
# In the following, parameter ``scheduler`` is an LR scheduler object from
# ``torch.optim.lr_scheduler``.

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
            if phase == 'train':
                scheduler.step(epoch_loss)
            
        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %% [markdown]
# Visualizing the model predictions
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# Generic function to display predictions for a few images

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
classes = ('Bread', 'DairyProduct', 'Dessert', 'Egg', 'Friedfood',
    'Meat', 'Noodles-Pasta', 'Rice', 'Seafood', 'Soup', 'Vegetable')

# %%
model_ft = models.resnet18(pretrained=False)
num_ftrs = model_ft.fc.in_features
model_ft.fc = nn.Linear(num_ftrs, 11)

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.5 every 10 epochs
exp_lr_scheduler = lr_scheduler.ReduceLROnPlateau(
    optimizer_ft, mode='min', patience=6, verbose=True)

# %% [markdown]
# Train and evaluate
# ^^^^^^^^^^^^^^^^^^
#
# It should take around 15-25 min on CPU. On GPU though, it takes less than a
# minute.

# %%
model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=1)
# Out:
# Epoch 0/149
# ----------
# train Loss: 2.1455 Acc: 0.2361
# val Loss: 1.9933 Acc: 0.2741
#
# Epoch 1/149
# ----------
# train Loss: 1.9613 Acc: 0.3096
# val Loss: 1.9619 Acc: 0.3187
#
# Epoch 2/149
# ----------
# train Loss: 1.8641 Acc: 0.3483
# val Loss: 1.7854 Acc: 0.3945
#
# Epoch 3/149
# ----------
# train Loss: 1.8259 Acc: 0.3574
# val Loss: 1.7296 Acc: 0.3746
#
# Epoch 4/149
# ----------
# train Loss: 1.7631 Acc: 0.3886
# val Loss: 1.6909 Acc: 0.4327
#
# Epoch 5/149
# ----------
# train Loss: 1.7200 Acc: 0.4039
# val Loss: 1.6622 Acc: 0.4370
#
# Epoch 6/149
# ----------
# train Loss: 1.6964 Acc: 0.4196
# val Loss: 1.5444 Acc: 0.4845
#
# Epoch 7/149
# ----------
# train Loss: 1.6528 Acc: 0.4258
# val Loss: 1.6194 Acc: 0.4405
#
# Epoch 8/149
# ----------
# train Loss: 1.6226 Acc: 0.4433
# val Loss: 1.5235 Acc: 0.4834
#
# Epoch 9/149
# ----------
# train Loss: 1.5864 Acc: 0.4558
# val Loss: 1.4748 Acc: 0.5044
#
# Epoch 10/149
# ----------
# train Loss: 1.5474 Acc: 0.4744
# val Loss: 1.4474 Acc: 0.5190
#
# Epoch 11/149
# ----------
# train Loss: 1.5296 Acc: 0.4722
# val Loss: 1.3836 Acc: 0.5437
#
# Epoch 12/149
# ----------
# train Loss: 1.4912 Acc: 0.4904
# val Loss: 1.4732 Acc: 0.5050
#
# Epoch 13/149
# ----------
# train Loss: 1.4836 Acc: 0.4960
# val Loss: 1.3605 Acc: 0.5434
#
# Epoch 14/149
# ----------
# train Loss: 1.4430 Acc: 0.5045
# val Loss: 1.4033 Acc: 0.5364
#
# Epoch 15/149
# ----------
# train Loss: 1.4054 Acc: 0.5193
# val Loss: 1.5214 Acc: 0.4994
#
# Epoch 16/149
# ----------
# train Loss: 1.3984 Acc: 0.5226
# val Loss: 1.3377 Acc: 0.5574
#
# Epoch 17/149
# ----------
# train Loss: 1.3696 Acc: 0.5293
# val Loss: 1.3417 Acc: 0.5493
#
# Epoch 18/149
# ----------
# train Loss: 1.3528 Acc: 0.5384
# val Loss: 1.3248 Acc: 0.5633
#
# Epoch 19/149
# ----------
# train Loss: 1.3296 Acc: 0.5457
# val Loss: 1.3373 Acc: 0.5618
#
# Epoch 20/149
# ----------
# train Loss: 1.3270 Acc: 0.5486
# val Loss: 1.2272 Acc: 0.5889
#
# Epoch 21/149
# ----------
# train Loss: 1.2990 Acc: 0.5609
# val Loss: 1.3482 Acc: 0.5592
#
# Epoch 22/149
# ----------
# train Loss: 1.2854 Acc: 0.5649
# val Loss: 1.2396 Acc: 0.5991
#
# Epoch 23/149
# ----------
# train Loss: 1.2708 Acc: 0.5707
# val Loss: 1.1804 Acc: 0.6146
#
# Epoch 24/149
# ----------
# train Loss: 1.2464 Acc: 0.5777
# val Loss: 1.2354 Acc: 0.5980
#
# Epoch 25/149
# ----------
# train Loss: 1.2404 Acc: 0.5807
# val Loss: 1.1458 Acc: 0.6332
#
# Epoch 26/149
# ----------
# train Loss: 1.2277 Acc: 0.5852
# val Loss: 1.1743 Acc: 0.6041
#
# Epoch 27/149
# ----------
# train Loss: 1.2141 Acc: 0.5838
# val Loss: 1.2413 Acc: 0.5921
#
# Epoch 28/149
# ----------
# train Loss: 1.1821 Acc: 0.5970
# val Loss: 1.1980 Acc: 0.6064
#
# Epoch 29/149
# ----------
# train Loss: 1.1931 Acc: 0.5942
# val Loss: 1.1518 Acc: 0.6108
#
# Epoch 30/149
# ----------
# train Loss: 1.1514 Acc: 0.6131
# val Loss: 1.1977 Acc: 0.6000
#
# Epoch 31/149
# ----------
# train Loss: 1.1430 Acc: 0.6138
# val Loss: 1.1771 Acc: 0.6102
#
# Epoch 32/149
# ----------
# train Loss: 1.1450 Acc: 0.6138
# val Loss: 1.1743 Acc: 0.6044
#
# Epoch 33/149
# ----------
# train Loss: 1.1342 Acc: 0.6164
# val Loss: 1.2692 Acc: 0.5843
#
# Epoch 34/149
# ----------
# train Loss: 1.1093 Acc: 0.6289
# val Loss: 1.0923 Acc: 0.6440
#
# Epoch 35/149
# ----------
# train Loss: 1.0961 Acc: 0.6282
# val Loss: 1.0809 Acc: 0.6423
#
# Epoch 36/149
# ----------
# train Loss: 1.0942 Acc: 0.6268
# val Loss: 1.0789 Acc: 0.6461
#
# Epoch 37/149
# ----------
# train Loss: 1.0849 Acc: 0.6309
# val Loss: 1.1258 Acc: 0.6242
#
# Epoch 38/149
# ----------
# train Loss: 1.0714 Acc: 0.6420
# val Loss: 1.1809 Acc: 0.6096
#
# Epoch 39/149
# ----------
# train Loss: 1.0576 Acc: 0.6461
# val Loss: 1.0885 Acc: 0.6458
#
# Epoch 40/149
# ----------
# train Loss: 1.0622 Acc: 0.6410
# val Loss: 1.1331 Acc: 0.6216
#
# Epoch 41/149
# ----------
# train Loss: 1.0274 Acc: 0.6539
# val Loss: 1.1639 Acc: 0.6149
#
# Epoch 42/149
# ----------
# train Loss: 1.0231 Acc: 0.6562
# val Loss: 1.0158 Acc: 0.6688
#
# Epoch 43/149
# ----------
# train Loss: 1.0144 Acc: 0.6542
# val Loss: 1.0744 Acc: 0.6338
#
# Epoch 44/149
# ----------
# train Loss: 0.9987 Acc: 0.6673
# val Loss: 1.1255 Acc: 0.6420
#
# Epoch 45/149
# ----------
# train Loss: 0.9856 Acc: 0.6697
# val Loss: 1.1113 Acc: 0.6429
#
# Epoch 46/149
# ----------
# train Loss: 0.9791 Acc: 0.6716
# val Loss: 1.0125 Acc: 0.6621
#
# Epoch 47/149
# ----------
# train Loss: 0.9888 Acc: 0.6686
# val Loss: 1.0873 Acc: 0.6464
#
# Epoch 48/149
# ----------
# train Loss: 0.9584 Acc: 0.6791
# val Loss: 1.0626 Acc: 0.6519
#
# Epoch 49/149
# ----------
# train Loss: 0.9703 Acc: 0.6780
# val Loss: 1.0244 Acc: 0.6767
#
# Epoch 50/149
# ----------
# train Loss: 0.9565 Acc: 0.6762
# val Loss: 1.0823 Acc: 0.6618
#
# Epoch 51/149
# ----------
# train Loss: 0.9305 Acc: 0.6857
# val Loss: 1.1126 Acc: 0.6446
#
# Epoch 52/149
# ----------
# train Loss: 0.9358 Acc: 0.6824
# val Loss: 0.9709 Acc: 0.6857
#
# Epoch 53/149
# ----------
# train Loss: 0.9142 Acc: 0.6887
# val Loss: 1.0667 Acc: 0.6598
#
# Epoch 54/149
# ----------
# train Loss: 0.9163 Acc: 0.6920
# val Loss: 1.0735 Acc: 0.6618
#
# Epoch 55/149
# ----------
# train Loss: 0.8981 Acc: 0.6922
# val Loss: 1.0816 Acc: 0.6507
#
# Epoch 56/149
# ----------
# train Loss: 0.9015 Acc: 0.6972
# val Loss: 0.9522 Acc: 0.6848
#
# Epoch 57/149
# ----------
# train Loss: 0.8794 Acc: 0.7065
# val Loss: 1.0034 Acc: 0.6738
#
# Epoch 58/149
# ----------
# train Loss: 0.8885 Acc: 0.7005
# val Loss: 0.9774 Acc: 0.6863
#
# Epoch 59/149
# ----------
# train Loss: 0.8675 Acc: 0.7104
# val Loss: 0.9929 Acc: 0.6872
#
# Epoch 60/149
# ----------
# train Loss: 0.8594 Acc: 0.7097
# val Loss: 0.9832 Acc: 0.6886
#
# Epoch 61/149
# ----------
# train Loss: 0.8757 Acc: 0.7084
# val Loss: 0.9390 Acc: 0.6878
#
# Epoch 62/149
# ----------
# train Loss: 0.8326 Acc: 0.7214
# val Loss: 1.0590 Acc: 0.6574
#
# Epoch 63/149
# ----------
# train Loss: 0.8460 Acc: 0.7207
# val Loss: 0.9232 Acc: 0.7085
#
# Epoch 64/149
# ----------
# train Loss: 0.8465 Acc: 0.7139
# val Loss: 0.9684 Acc: 0.6880
#
# Epoch 65/149
# ----------
# train Loss: 0.8249 Acc: 0.7262
# val Loss: 1.0048 Acc: 0.6831
#
# Epoch 66/149
# ----------
# train Loss: 0.8112 Acc: 0.7257
# val Loss: 1.0726 Acc: 0.6589
#
# Epoch 67/149
# ----------
# train Loss: 0.8126 Acc: 0.7311
# val Loss: 1.0186 Acc: 0.6714
#
# Epoch 68/149
# ----------
# train Loss: 0.8052 Acc: 0.7310
# val Loss: 0.9093 Acc: 0.7192
#
# Epoch 69/149
# ----------
# train Loss: 0.7985 Acc: 0.7327
# val Loss: 0.9335 Acc: 0.7006
#
# Epoch 70/149
# ----------
# train Loss: 0.7932 Acc: 0.7348
# val Loss: 0.9253 Acc: 0.7026
#
# Epoch 71/149
# ----------
# train Loss: 0.7752 Acc: 0.7420
# val Loss: 1.0683 Acc: 0.6603
#
# Epoch 72/149
# ----------
# train Loss: 0.7887 Acc: 0.7391
# val Loss: 1.1178 Acc: 0.6630
#
# Epoch 73/149
# ----------
# train Loss: 0.7686 Acc: 0.7435
# val Loss: 0.9522 Acc: 0.6924
#
# Epoch 74/149
# ----------
# train Loss: 0.7629 Acc: 0.7446
# val Loss: 1.0401 Acc: 0.6743
#
# Epoch 75/149
# ----------
# train Loss: 0.7618 Acc: 0.7420
# val Loss: 0.9369 Acc: 0.7073
#
# Epoch 76/149
# ----------
# train Loss: 0.7605 Acc: 0.7466
# val Loss: 0.8884 Acc: 0.7085
#
# Epoch 77/149
# ----------
# train Loss: 0.7549 Acc: 0.7506
# val Loss: 0.9034 Acc: 0.7090
#
# Epoch 78/149
# ----------
# train Loss: 0.7390 Acc: 0.7519
# val Loss: 0.9246 Acc: 0.7131
#
# Epoch 79/149
# ----------
# train Loss: 0.7192 Acc: 0.7574
# val Loss: 0.9451 Acc: 0.6980
#
# Epoch 80/149
# ----------
# train Loss: 0.7247 Acc: 0.7597
# val Loss: 0.9523 Acc: 0.7032
#
# Epoch 81/149
# ----------
# train Loss: 0.7218 Acc: 0.7640
# val Loss: 0.9432 Acc: 0.7085
#
# Epoch 82/149
# ----------
# train Loss: 0.7353 Acc: 0.7576
# val Loss: 0.9160 Acc: 0.7163
#
# Epoch 83/149
# ----------
# train Loss: 0.7056 Acc: 0.7678
# val Loss: 0.9720 Acc: 0.6983
#
# Epoch 84/149
# ----------
# train Loss: 0.7158 Acc: 0.7660
# val Loss: 1.0085 Acc: 0.6974
#
# Epoch 85/149
# ----------
# train Loss: 0.7001 Acc: 0.7697
# val Loss: 1.0042 Acc: 0.6790
#
# Epoch 86/149
# ----------
# train Loss: 0.7080 Acc: 0.7668
# val Loss: 0.8875 Acc: 0.7251
#
# Epoch 87/149
# ----------
# train Loss: 0.6972 Acc: 0.7698
# val Loss: 0.9256 Acc: 0.7172
#
# Epoch 88/149
# ----------
# train Loss: 0.6780 Acc: 0.7795
# val Loss: 0.9507 Acc: 0.7099
#
# Epoch 89/149
# ----------
# train Loss: 0.7035 Acc: 0.7636
# val Loss: 1.0088 Acc: 0.7044
#
# Epoch 90/149
# ----------
# train Loss: 0.6515 Acc: 0.7850
# val Loss: 1.0257 Acc: 0.6810
#
# Epoch 91/149
# ----------
# train Loss: 0.6863 Acc: 0.7691
# val Loss: 0.9472 Acc: 0.7125
#
# Epoch 92/149
# ----------
# train Loss: 0.6859 Acc: 0.7725
# val Loss: 0.9670 Acc: 0.7015
#
# Epoch 93/149
# ----------
# train Loss: 0.6741 Acc: 0.7785
# val Loss: 1.0191 Acc: 0.7047
#
# Epoch 94/149
# ----------
# train Loss: 0.6487 Acc: 0.7844
# val Loss: 0.9469 Acc: 0.7128
#
# Epoch 95/149
# ----------
# train Loss: 0.6352 Acc: 0.7913
# val Loss: 1.0202 Acc: 0.6945
#
# Epoch 96/149
# ----------
# train Loss: 0.6578 Acc: 0.7782
# val Loss: 1.0241 Acc: 0.6892
#
# Epoch 97/149
# ----------
# train Loss: 0.6285 Acc: 0.7954
# val Loss: 0.8752 Acc: 0.7373
#
# Epoch 98/149
# ----------
# train Loss: 0.6607 Acc: 0.7794
# val Loss: 0.9919 Acc: 0.6994
#
# Epoch 99/149
# ----------
# train Loss: 0.6445 Acc: 0.7882
# val Loss: 1.0358 Acc: 0.7070
#
# Epoch 100/149
# ----------
# train Loss: 0.6165 Acc: 0.8013
# val Loss: 0.9296 Acc: 0.7192
#
# Epoch 101/149
# ----------
# train Loss: 0.6060 Acc: 0.8004
# val Loss: 0.9106 Acc: 0.7230
#
# Epoch 102/149
# ----------
# train Loss: 0.6096 Acc: 0.7968
# val Loss: 1.0069 Acc: 0.7108
#
# Epoch 103/149
# ----------
# train Loss: 0.6102 Acc: 0.7969
# val Loss: 1.1098 Acc: 0.6726
#
# Epoch 104/149
# ----------
# train Loss: 0.5937 Acc: 0.8044
# val Loss: 0.9365 Acc: 0.7134
#
# Epoch 105/149
# ----------
# train Loss: 0.5894 Acc: 0.8049
# val Loss: 0.9534 Acc: 0.7125
#
# Epoch 106/149
# ----------
# train Loss: 0.6055 Acc: 0.7999
# val Loss: 0.9132 Acc: 0.7259
#
# Epoch 107/149
# ----------
# train Loss: 0.5929 Acc: 0.8060
# val Loss: 0.9225 Acc: 0.7271
#
# Epoch 108/149
# ----------
# train Loss: 0.5712 Acc: 0.8127
# val Loss: 0.9563 Acc: 0.7207
#
# Epoch 109/149
# ----------
# train Loss: 0.5737 Acc: 0.8079
# val Loss: 0.9183 Acc: 0.7315
#
# Epoch 110/149
# ----------
# train Loss: 0.5827 Acc: 0.8092
# val Loss: 1.0049 Acc: 0.7143
#
# Epoch 111/149
# ----------
# train Loss: 0.5689 Acc: 0.8158
# val Loss: 0.9470 Acc: 0.7198
#
# Epoch 112/149
# ----------
# train Loss: 0.5877 Acc: 0.8031
# val Loss: 0.9355 Acc: 0.7207
#
# Epoch 113/149
# ----------
# train Loss: 0.5605 Acc: 0.8208
# val Loss: 0.9271 Acc: 0.7289
#
# Epoch 114/149
# ----------
# train Loss: 0.5574 Acc: 0.8154
# val Loss: 0.9779 Acc: 0.7195
#
# Epoch 115/149
# ----------
# train Loss: 0.5827 Acc: 0.8087
# val Loss: 0.8917 Acc: 0.7321
#
# Epoch 116/149
# ----------
# train Loss: 0.5714 Acc: 0.8124
# val Loss: 0.9311 Acc: 0.7327
#
# Epoch 117/149
# ----------
# train Loss: 0.5429 Acc: 0.8208
# val Loss: 0.9466 Acc: 0.7271
#
# Epoch 118/149
# ----------
# train Loss: 0.5520 Acc: 0.8140
# val Loss: 0.9876 Acc: 0.7192
#
# Epoch 119/149
# ----------
# train Loss: 0.5391 Acc: 0.8199
# val Loss: 0.9187 Acc: 0.7373
#
# Epoch 120/149
# ----------
# train Loss: 0.5330 Acc: 0.8276
# val Loss: 0.9509 Acc: 0.7294
#
# Epoch 121/149
# ----------
# train Loss: 0.5428 Acc: 0.8180
# val Loss: 0.9157 Acc: 0.7254
#
# Epoch 122/149
# ----------
# train Loss: 0.5390 Acc: 0.8221
# val Loss: 0.8858 Acc: 0.7327
#
# Epoch 123/149
# ----------
# train Loss: 0.5311 Acc: 0.8260
# val Loss: 0.9653 Acc: 0.7230
#
# Epoch 124/149
# ----------
# train Loss: 0.5249 Acc: 0.8253
# val Loss: 0.8616 Acc: 0.7504
#
# Epoch 125/149
# ----------
# train Loss: 0.5329 Acc: 0.8284
# val Loss: 0.9220 Acc: 0.7327
#
# Epoch 126/149
# ----------
# train Loss: 0.5193 Acc: 0.8276
# val Loss: 0.9844 Acc: 0.7146
#
# Epoch 127/149
# ----------
# train Loss: 0.5099 Acc: 0.8346
# val Loss: 0.9043 Acc: 0.7329
#
# Epoch 128/149
# ----------
# train Loss: 0.5048 Acc: 0.8345
# val Loss: 0.8915 Acc: 0.7329
#
# Epoch 129/149
# ----------
# train Loss: 0.4980 Acc: 0.8364
# val Loss: 1.0240 Acc: 0.7140
#
# Epoch 130/149
# ----------
# train Loss: 0.4993 Acc: 0.8363
# val Loss: 0.8690 Acc: 0.7431
#
# Epoch 131/149
# ----------
# train Loss: 0.5034 Acc: 0.8351
# val Loss: 0.8597 Acc: 0.7493
#
# Epoch 132/149
# ----------
# train Loss: 0.4949 Acc: 0.8375
# val Loss: 0.9228 Acc: 0.7327
#
# Epoch 133/149
# ----------
# train Loss: 0.5033 Acc: 0.8343
# val Loss: 1.0394 Acc: 0.7047
#
# Epoch 134/149
# ----------
# train Loss: 0.4858 Acc: 0.8404
# val Loss: 0.9578 Acc: 0.7362
#
# Epoch 135/149
# ----------
# train Loss: 0.5093 Acc: 0.8358
# val Loss: 0.9572 Acc: 0.7312
#
# Epoch 136/149
# ----------
# train Loss: 0.4940 Acc: 0.8371
# val Loss: 0.9903 Acc: 0.7271
#
# Epoch 137/149
# ----------
# train Loss: 0.4692 Acc: 0.8482
# val Loss: 0.8975 Acc: 0.7382
#
# Epoch 138/149
# ----------
# train Loss: 0.4893 Acc: 0.8381
# val Loss: 0.9818 Acc: 0.7280
#
# Epoch 139/149
# ----------
# train Loss: 0.4672 Acc: 0.8484
# val Loss: 0.8854 Acc: 0.7501
#
# Epoch 140/149
# ----------
# train Loss: 0.4695 Acc: 0.8502
# val Loss: 0.9883 Acc: 0.7297
#
# Epoch 141/149
# ----------
# train Loss: 0.4768 Acc: 0.8423
# val Loss: 0.9050 Acc: 0.7388
#
# Epoch 142/149
# ----------
# train Loss: 0.4866 Acc: 0.8408
# val Loss: 0.9405 Acc: 0.7338
#
# Epoch 143/149
# ----------
# train Loss: 0.4739 Acc: 0.8441
# val Loss: 1.0627 Acc: 0.7125
#
# Epoch 144/149
# ----------
# train Loss: 0.4533 Acc: 0.8512
# val Loss: 0.9407 Acc: 0.7300
#
# Epoch 145/149
# ----------
# train Loss: 0.4710 Acc: 0.8442
# val Loss: 0.9372 Acc: 0.7327
#
# Epoch 146/149
# ----------
# train Loss: 0.4384 Acc: 0.8583
# val Loss: 0.9790 Acc: 0.7289
#
# Epoch 147/149
# ----------
# train Loss: 0.4610 Acc: 0.8491
# val Loss: 0.8973 Acc: 0.7478
#
# Epoch 148/149
# ----------
# train Loss: 0.4373 Acc: 0.8583
# val Loss: 0.9524 Acc: 0.7356
#
# Epoch 149/149
# ----------
# train Loss: 0.4637 Acc: 0.8518
# val Loss: 0.9348 Acc: 0.7519
#
# Training complete in 183m 24s
# Best val Acc: 0.751895

# %%
visualize_model(model_ft)

# %%
print('==> Saving model..')
#save entire model
model_name = './model-' + str(time.time()) + '.pt'
torch.save(model_ft, model_name)

print('Finished Saving')
# Out:
# ==> Saving model..
# Finished Saving

# %%
print('==> Loading model..')

#If you save the entire model
model_name = './model-lab2-1-transform v1.pt'
model_ft = torch.load(model_name)

print('Finished Loading')
# Out:
# ==> Loading model..
# Finished Loading

# %%
######################
# Test the Model
######################
correct = 0
total = 0
running_loss = 0.0

class_correct = list(0. for i in range(11))
class_total = list(0. for i in range(11))

with torch.no_grad():
    for data in dataloaders['test']:
        images, labels = data

        #if device == 'cuda':
        #    images = images.cuda(0)
        #    labels = labels.cuda(0)
        #else:
        #    images = images.cpu()
        #    labels = labels.cpu()
        images = images.to(device)
        labels = labels.to(device)

        outputs = model_ft(images)
        _, predicted = torch.max(outputs, 1)
        
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

        loss = criterion(outputs, labels)
        running_loss += loss.item()

        c = (predicted == labels).squeeze()
        #print(predicted)
        #print(labels.size(0))
        #print(c)
        for i in range(labels.size(0)):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1

print('Accuracy of the network on the %d test images: %.2f%%, and loss is: %.3f'
      % (total, 100 * correct / total, running_loss / total))

for i in range(11):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of the network on the 3347 test images: 77.47%, and loss is: 0.099
# Accuracy of Bread : 69 %
# Accuracy of DairyProduct : 51 %
# Accuracy of Dessert : 92 %
# Accuracy of   Egg : 62 %
# Accuracy of Friedfood : 76 %
# Accuracy of  Meat : 84 %
# Accuracy of Noodles-Pasta : 81 %
# Accuracy of  Rice : 74 %
# Accuracy of Seafood : 85 %
# Accuracy of  Soup : 86 %
# Accuracy of Vegetable : 86 %
