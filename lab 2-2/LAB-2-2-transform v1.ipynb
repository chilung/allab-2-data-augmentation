# %%
# %matplotlib inline

# %%
# License: BSD
# Author: Sasank Chilamkurthy

from __future__ import print_function, division

import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy

plt.ion()   # interactive mode

# %%
# Data augmentation and normalization for training
# Just normalization for validation
test_data = 'food_test2'
data_transforms = {
    'train': transforms.Compose([
        transforms.RandomHorizontalFlip(),
        transforms.RandomVerticalFlip(),
        transforms.RandomRotation((-180,180)),
        transforms.RandomAffine(degrees=(-30,30), shear=(-20,20)),
        #transforms.Resize(256),
        #transforms.CenterCrop(224),
        transforms.RandomResizedCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.5548, 0.4508, 0.3435], [0.2281, 0.2384, 0.2376])
    ]),
    'val': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.5604, 0.4540, 0.3481], [0.2260, 0.2367, 0.2352])
    ]),
    test_data: transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.5604, 0.4540, 0.3481], [0.2260, 0.2367, 0.2352])
    ]),
}

data_dir = '../data/food/'
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x),
                                          data_transforms[x])
                  for x in ['train', 'val', test_data]}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=64,
                                             shuffle=True, num_workers=4)
              for x in ['train', 'val', test_data]}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'val', test_data]}
class_names = image_datasets['train'].classes

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
#device = torch.device("cpu")
# Out:
# cuda:0

# %% [markdown]
# Visualize a few images
# ^^^^^^^^^^^^^^^^^^^^^^
# Let's visualize a few training images so as to understand the data
# augmentations.

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.5548, 0.4508, 0.3435])
    std = np.array([0.2281, 0.2384, 0.2376])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])

# %% [markdown]
# Training the model
# ------------------
#
# Now, let's write a general function to train a model. Here, we will
# illustrate:
#
# -  Scheduling the learning rate
# -  Saving the best model
#
# In the following, parameter ``scheduler`` is an LR scheduler object from
# ``torch.optim.lr_scheduler``.

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
            if phase == 'train':
                scheduler.step(epoch_loss)
            
        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %% [markdown]
# Visualizing the model predictions
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# Generic function to display predictions for a few images

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['val']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                ax.set_title('predicted: {}'.format(class_names[preds[j]]))
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %%
classes = ('Bread', 'DairyProduct', 'Dessert', 'Egg', 'Friedfood',
    'Meat', 'Noodles-Pasta', 'Rice', 'Seafood', 'Soup', 'Vegetable-Fruit')

# %%
model_ft = models.resnet18(pretrained=True)
num_ftrs = model_ft.fc.in_features
model_ft.fc = nn.Linear(num_ftrs, 11)

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.5 every 10 epochs
exp_lr_scheduler = lr_scheduler.ReduceLROnPlateau(
    optimizer_ft, mode='min', patience=6, verbose=True)

# %% [markdown]
# Train and evaluate
# ^^^^^^^^^^^^^^^^^^
#
# It should take around 15-25 min on CPU. On GPU though, it takes less than a
# minute.

# %%
model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=150)
# Out:
# Epoch 0/149
# ----------
# train Loss: 1.4449 Acc: 0.5428
# val Loss: 0.7736 Acc: 0.7542
#
# Epoch 1/149
# ----------
# train Loss: 0.8466 Acc: 0.7317
# val Loss: 0.5952 Acc: 0.8114
#
# Epoch 2/149
# ----------
# train Loss: 0.7107 Acc: 0.7696
# val Loss: 0.5316 Acc: 0.8303
#
# Epoch 3/149
# ----------
# train Loss: 0.6523 Acc: 0.7860
# val Loss: 0.4778 Acc: 0.8449
#
# Epoch 4/149
# ----------
# train Loss: 0.6120 Acc: 0.8007
# val Loss: 0.4530 Acc: 0.8589
#
# Epoch 5/149
# ----------
# train Loss: 0.5657 Acc: 0.8166
# val Loss: 0.4389 Acc: 0.8580
#
# Epoch 6/149
# ----------
# train Loss: 0.5505 Acc: 0.8204
# val Loss: 0.4124 Acc: 0.8729
#
# Epoch 7/149
# ----------
# train Loss: 0.5187 Acc: 0.8337
# val Loss: 0.4182 Acc: 0.8586
#
# Epoch 8/149
# ----------
# train Loss: 0.4985 Acc: 0.8385
# val Loss: 0.4119 Acc: 0.8671
#
# Epoch 9/149
# ----------
# train Loss: 0.4834 Acc: 0.8435
# val Loss: 0.3869 Acc: 0.8708
#
# Epoch 10/149
# ----------
# train Loss: 0.4733 Acc: 0.8433
# val Loss: 0.3913 Acc: 0.8746
#
# Epoch 11/149
# ----------
# train Loss: 0.4664 Acc: 0.8484
# val Loss: 0.3699 Acc: 0.8825
#
# Epoch 12/149
# ----------
# train Loss: 0.4372 Acc: 0.8552
# val Loss: 0.3580 Acc: 0.8822
#
# Epoch 13/149
# ----------
# train Loss: 0.4362 Acc: 0.8568
# val Loss: 0.3537 Acc: 0.8843
#
# Epoch 14/149
# ----------
# train Loss: 0.4378 Acc: 0.8559
# val Loss: 0.3347 Acc: 0.8883
#
# Epoch 15/149
# ----------
# train Loss: 0.4143 Acc: 0.8628
# val Loss: 0.3473 Acc: 0.8904
#
# Epoch 16/149
# ----------
# train Loss: 0.3911 Acc: 0.8696
# val Loss: 0.3439 Acc: 0.8886
#
# Epoch 17/149
# ----------
# train Loss: 0.3965 Acc: 0.8739
# val Loss: 0.3333 Acc: 0.8898
#
# Epoch 18/149
# ----------
# train Loss: 0.3965 Acc: 0.8702
# val Loss: 0.3403 Acc: 0.8942
#
# Epoch 19/149
# ----------
# train Loss: 0.3725 Acc: 0.8784
# val Loss: 0.3341 Acc: 0.8892
#
# Epoch 20/149
# ----------
# train Loss: 0.3752 Acc: 0.8803
# val Loss: 0.3378 Acc: 0.8927
#
# Epoch 21/149
# ----------
# train Loss: 0.3605 Acc: 0.8817
# val Loss: 0.3434 Acc: 0.8910
#
# Epoch 22/149
# ----------
# train Loss: 0.3655 Acc: 0.8766
# val Loss: 0.3338 Acc: 0.8950
#
# Epoch 23/149
# ----------
# train Loss: 0.3471 Acc: 0.8835
# val Loss: 0.3187 Acc: 0.8962
#
# Epoch 24/149
# ----------
# train Loss: 0.3502 Acc: 0.8839
# val Loss: 0.3488 Acc: 0.8924
#
# Epoch 25/149
# ----------
# train Loss: 0.3369 Acc: 0.8870
# val Loss: 0.3512 Acc: 0.8950
#
# Epoch 26/149
# ----------
# train Loss: 0.3497 Acc: 0.8851
# val Loss: 0.3299 Acc: 0.8968
#
# Epoch 27/149
# ----------
# train Loss: 0.3340 Acc: 0.8929
# val Loss: 0.3397 Acc: 0.8933
#
# Epoch 28/149
# ----------
# train Loss: 0.3243 Acc: 0.8912
# val Loss: 0.3193 Acc: 0.9015
#
# Epoch 29/149
# ----------
# train Loss: 0.3309 Acc: 0.8924
# val Loss: 0.3157 Acc: 0.9017
#
# Epoch 30/149
# ----------
# train Loss: 0.3145 Acc: 0.8957
# val Loss: 0.3331 Acc: 0.9000
#
# Epoch 31/149
# ----------
# train Loss: 0.3096 Acc: 0.8998
# val Loss: 0.3358 Acc: 0.8968
#
# Epoch 32/149
# ----------
# train Loss: 0.3034 Acc: 0.9004
# val Loss: 0.3183 Acc: 0.9006
#
# Epoch 33/149
# ----------
# train Loss: 0.3066 Acc: 0.8959
# val Loss: 0.3353 Acc: 0.8942
#
# Epoch 34/149
# ----------
# train Loss: 0.3033 Acc: 0.9018
# val Loss: 0.3196 Acc: 0.9032
#
# Epoch 35/149
# ----------
# train Loss: 0.2965 Acc: 0.9031
# val Loss: 0.3179 Acc: 0.8974
#
# Epoch 88/149
# ----------
# train Loss: 0.1837 Acc: 0.9401
# val Loss: 0.3513 Acc: 0.9079
#
# Epoch 89/149
# ----------
# train Loss: 0.1846 Acc: 0.9388
# val Loss: 0.3399 Acc: 0.9058
#
# Epoch 90/149
# ----------
# train Loss: 0.1823 Acc: 0.9408
# val Loss: 0.3375 Acc: 0.9070
#
# Epoch 91/149
# ----------
# train Loss: 0.1877 Acc: 0.9376
# val Loss: 0.3555 Acc: 0.9047
#
# Epoch 92/149
# ----------
# train Loss: 0.1759 Acc: 0.9442
# val Loss: 0.3394 Acc: 0.9079
#
# Epoch 93/149
# ----------
# train Loss: 0.1815 Acc: 0.9393
# val Loss: 0.3528 Acc: 0.9026
#
# Epoch 94/149
# ----------
# train Loss: 0.1679 Acc: 0.9461
# val Loss: 0.3230 Acc: 0.9122
#
# Epoch 95/149
# ----------
# train Loss: 0.1830 Acc: 0.9412
# val Loss: 0.3513 Acc: 0.9050
#
# Epoch 96/149
# ----------
# train Loss: 0.1699 Acc: 0.9441
# val Loss: 0.3693 Acc: 0.9032
#
# Epoch 97/149
# ----------
# train Loss: 0.1718 Acc: 0.9435
# val Loss: 0.3564 Acc: 0.9064
#
# Epoch 98/149
# ----------
# train Loss: 0.1782 Acc: 0.9434
# val Loss: 0.3597 Acc: 0.9032
#
# Epoch 99/149
# ----------
# train Loss: 0.1720 Acc: 0.9455
# val Loss: 0.3571 Acc: 0.9050
#
# Epoch 100/149
# ----------
# train Loss: 0.1690 Acc: 0.9455
# val Loss: 0.3662 Acc: 0.9015
#
# Epoch 101/149
# ----------
# train Loss: 0.1826 Acc: 0.9413
# Epoch   101: reducing learning rate of group 0 to 1.0000e-04.
# val Loss: 0.3909 Acc: 0.9003
#
# Epoch 102/149
# ----------
# train Loss: 0.1641 Acc: 0.9477
# val Loss: 0.3580 Acc: 0.9035
#
# Epoch 103/149
# ----------
# train Loss: 0.1561 Acc: 0.9471
# val Loss: 0.3536 Acc: 0.9070
#
# Epoch 104/149
# ----------
# train Loss: 0.1539 Acc: 0.9495
# val Loss: 0.3545 Acc: 0.9079
#
# Epoch 105/149
# ----------
# train Loss: 0.1513 Acc: 0.9513
# val Loss: 0.3510 Acc: 0.9102
#
# Epoch 106/149
# ----------
# train Loss: 0.1567 Acc: 0.9505
# val Loss: 0.3477 Acc: 0.9105
#
# Epoch 107/149
# ----------
# train Loss: 0.1618 Acc: 0.9491
# val Loss: 0.3509 Acc: 0.9076
#
# Epoch 108/149
# ----------
# train Loss: 0.1524 Acc: 0.9502
# val Loss: 0.3404 Acc: 0.9093
#
# Epoch 109/149
# ----------
# train Loss: 0.1471 Acc: 0.9533
# val Loss: 0.3463 Acc: 0.9067
#
# Epoch 110/149
# ----------
# train Loss: 0.1466 Acc: 0.9553
# val Loss: 0.3480 Acc: 0.9047
#
# Epoch 111/149
# ----------
# train Loss: 0.1375 Acc: 0.9558
# val Loss: 0.3339 Acc: 0.9105
#
# Epoch 112/149
# ----------
# train Loss: 0.1420 Acc: 0.9566
# val Loss: 0.3451 Acc: 0.9090
#
# Epoch 113/149
# ----------
# train Loss: 0.1509 Acc: 0.9513
# val Loss: 0.3438 Acc: 0.9087
#
# Epoch 114/149
# ----------
# train Loss: 0.1496 Acc: 0.9530
# val Loss: 0.3410 Acc: 0.9087
#
# Epoch 115/149
# ----------
# train Loss: 0.1468 Acc: 0.9545
# val Loss: 0.3548 Acc: 0.9038
#
# Epoch 116/149
# ----------
# train Loss: 0.1399 Acc: 0.9563
# val Loss: 0.3458 Acc: 0.9076
#
# Epoch 117/149
# ----------
# train Loss: 0.1403 Acc: 0.9575
# val Loss: 0.3440 Acc: 0.9079
#
# Epoch 118/149
# ----------
# train Loss: 0.1403 Acc: 0.9556
# Epoch   118: reducing learning rate of group 0 to 1.0000e-05.
# val Loss: 0.3487 Acc: 0.9055
#
# Epoch 119/149
# ----------
# train Loss: 0.1500 Acc: 0.9525
# val Loss: 0.3485 Acc: 0.9052
#
# Epoch 120/149
# ----------
# train Loss: 0.1430 Acc: 0.9540
# val Loss: 0.3412 Acc: 0.9085
#
# Epoch 121/149
# ----------
# train Loss: 0.1488 Acc: 0.9551
# val Loss: 0.3340 Acc: 0.9079
#
# Epoch 122/149
# ----------
# train Loss: 0.1456 Acc: 0.9530
# val Loss: 0.3422 Acc: 0.9061
#
# Epoch 123/149
# ----------
# train Loss: 0.1357 Acc: 0.9579
# val Loss: 0.3472 Acc: 0.9076
#
# Epoch 124/149
# ----------
# train Loss: 0.1561 Acc: 0.9506
# val Loss: 0.3426 Acc: 0.9058
#
# Epoch 125/149
# ----------
# train Loss: 0.1474 Acc: 0.9542
# val Loss: 0.3337 Acc: 0.9099
#
# Epoch 126/149
# ----------
# train Loss: 0.1477 Acc: 0.9528
# val Loss: 0.3423 Acc: 0.9093
#
# Epoch 127/149
# ----------
# train Loss: 0.1537 Acc: 0.9536
# val Loss: 0.3494 Acc: 0.9076
#
# Epoch 128/149
# ----------
# train Loss: 0.1485 Acc: 0.9523
# val Loss: 0.3461 Acc: 0.9067
#
# Epoch 129/149
# ----------
# train Loss: 0.1336 Acc: 0.9577
# val Loss: 0.3430 Acc: 0.9105
#
# Epoch 130/149
# ----------
# train Loss: 0.1560 Acc: 0.9511
# val Loss: 0.3533 Acc: 0.9035
#
# Epoch 131/149
# ----------
# train Loss: 0.1438 Acc: 0.9546
# val Loss: 0.3371 Acc: 0.9108
#
# Epoch 132/149
# ----------
# train Loss: 0.1460 Acc: 0.9535
# val Loss: 0.3386 Acc: 0.9085
#
# Epoch 133/149
# ----------
# train Loss: 0.1428 Acc: 0.9533
# val Loss: 0.3366 Acc: 0.9102
#
# Epoch 134/149
# ----------
# train Loss: 0.1458 Acc: 0.9535
# val Loss: 0.3406 Acc: 0.9096
#
# Epoch 135/149
# ----------
# train Loss: 0.1420 Acc: 0.9560
# val Loss: 0.3468 Acc: 0.9064
#
# Epoch 136/149
# ----------
# train Loss: 0.1441 Acc: 0.9554
# Epoch   136: reducing learning rate of group 0 to 1.0000e-06.
# val Loss: 0.3474 Acc: 0.9058
#
# Epoch 137/149
# ----------
# train Loss: 0.1440 Acc: 0.9529
# val Loss: 0.3573 Acc: 0.9067
#
# Epoch 138/149
# ----------
# train Loss: 0.1527 Acc: 0.9513
# val Loss: 0.3430 Acc: 0.9067
#
# Epoch 139/149
# ----------
# train Loss: 0.1361 Acc: 0.9569
# val Loss: 0.3388 Acc: 0.9090
#
# Epoch 140/149
# ----------
# train Loss: 0.1434 Acc: 0.9565
# val Loss: 0.3380 Acc: 0.9085
#
# Epoch 141/149
# ----------
# train Loss: 0.1536 Acc: 0.9512
# val Loss: 0.3439 Acc: 0.9111
#
# Epoch 142/149
# ----------
# train Loss: 0.1515 Acc: 0.9524
# val Loss: 0.3370 Acc: 0.9099
#
# Epoch 143/149
# ----------
# train Loss: 0.1430 Acc: 0.9552
# Epoch   143: reducing learning rate of group 0 to 1.0000e-07.
# val Loss: 0.3452 Acc: 0.9079
#
# Epoch 144/149
# ----------
# train Loss: 0.1462 Acc: 0.9526
# val Loss: 0.3434 Acc: 0.9093
#
# Epoch 145/149
# ----------
# train Loss: 0.1332 Acc: 0.9582
# val Loss: 0.3387 Acc: 0.9085
#
# Epoch 146/149
# ----------
# train Loss: 0.1486 Acc: 0.9528
# val Loss: 0.3370 Acc: 0.9099
#
# Epoch 147/149
# ----------
# train Loss: 0.1384 Acc: 0.9542
# val Loss: 0.3412 Acc: 0.9087
#
# Epoch 148/149
# ----------
# train Loss: 0.1391 Acc: 0.9560
# val Loss: 0.3431 Acc: 0.9114
#
# Epoch 149/149
# ----------
# train Loss: 0.1401 Acc: 0.9559
# val Loss: 0.3453 Acc: 0.9061
#
# Training complete in 196m 26s
# Best val Acc: 0.912245

# %%
visualize_model(model_ft)

# %%
print('==> Saving model..')
#save entire model
model_name = './model-' + str(time.time()) + '.pt'
torch.save(model_ft, model_name)

print('Finished Saving')
# Out:
# ==> Saving model..
# Finished Saving

# %%
print('==> Loading model..')

#If you save the entire model
model_name = './model-lab2-2-aug.pt'
model_ft = torch.load(model_name)

print('Finished Loading')
# Out:
# ==> Loading model..
# Finished Loading

# %%
######################
# Test the Model
######################
correct = 0
total = 0
running_loss = 0.0

class_correct = list(0. for i in range(11))
class_total = list(0. for i in range(11))

with torch.no_grad():
    for data in dataloaders[test_data]:
        images, labels = data

        #if device == 'cuda':
        #    images = images.cuda(0)
        #    labels = labels.cuda(0)
        #else:
        #    images = images.cpu()
        #    labels = labels.cpu()
        images = images.to(device)
        labels = labels.to(device)

        outputs = model_ft(images)
        _, predicted = torch.max(outputs, 1)
        
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

        loss = criterion(outputs, labels)
        running_loss += loss.item()

        c = (predicted == labels).squeeze()
        #print(predicted)
        #print(labels.size(0))
        #print(c)
        for i in range(labels.size(0)):
            label = labels[i]
            class_correct[label] += c[i].item()
            class_total[label] += 1

print('Accuracy of the network on the %d test images: %.2f%%, and loss is: %.3f'
      % (total, 100 * correct / total, running_loss / total))

for i in range(11):
    print('Accuracy of %5s : %2d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of the network on the 3347 test images: 89.42%, and loss is: 0.006
# Accuracy of Bread : 80 %
# Accuracy of DairyProduct : 83 %
# Accuracy of Dessert : 96 %
# Accuracy of   Egg : 84 %
# Accuracy of Friedfood : 90 %
# Accuracy of  Meat : 88 %
# Accuracy of Noodles-Pasta : 90 %
# Accuracy of  Rice : 97 %
# Accuracy of Seafood : 87 %
# Accuracy of  Soup : 93 %
# Accuracy of Vegetable-Fruit : 93 %
